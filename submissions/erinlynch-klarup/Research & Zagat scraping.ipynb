# %% [markdown]
# First, background research:
#
# 'Instant Foodie: Predicting Expert Ratings From Grassroots', http://www.cs.cornell.edu/~chenhao/pub/instant-foodie.pdf
#
# In this paper, the authors use 'grassroots' yelp and google places scores to predict Zagat ratings. This has the complexity that Zagat ratings are three-pronged (food, service, decor) while the grassroots ratings are not. They draw on the fields of 'crowdsourced labeling' and 'collective filtering'. Latent factor models have become popular in collective filtering. The authors adapt this model, and "characterize both items and users as vectors in a space automatically inferred from observed ratings". Good discussion of challenges/biases in using grassroots reviews to predict expert reviews.
#
# On a less academic front, 538 compared yelp reviews with Michelin stars in NYC: http://fivethirtyeight.com/features/yelp-and-michelin-have-the-same-taste-in-new-york-restaurants/
#
# Nate Silver used a "VORB" approach -- "VORB is a formula that combines the review count and the star ratings." Review count is adjusted based on google searches of the restaurant. Silver finds that,
#     "The correlation between Yelp stars and Michelin stars is highly statistically significant.7 Indeed, it forms an eerily linear progression. The restaurants to have lost their Michelin stars have 3.83 Yelp stars on average, barely better than the average for all restaurants citywide."
#
# However, Silver finds that Yelp reviews are influenced by price (positively!):
#     "Controlling for their Michelin ratings, Yelp actually rates restaurants higher when they are more expensive. Each additional dollar sign (e.g. going from $$ to $$$) works out to 0.2 additional Yelp stars; the relationship is highly statistically significant."
#
# Cuisine also mattered:
#     "Another theme is that certain cuisines do poorly in Yelp as compared with their Michelin star ratings. Consider the four restaurants with the lowest VORB scores. They are (or were), respectively, a Vietnamese restaurant, a Malaysian restaurant, a Thai restaurant and a Chinese (Szechuan) restaurant."
#
# 'Zagat Overhauls Restaurant Review Ratings', http://www.wsj.com/articles/zagat-overhauls-restaurant-review-ratings-1469505614
# In July Zagat moved to a 1-5 star rating system, but still for the three categories of food, service, decor.
# "Under Google, Zagat no longer prints restaurant guides beyond New York, but it has retained its digital listings."
#
# Per this article: https://www.washingtonpost.com/lifestyle/food/dcs-food-scene-gets-a-prestigious-boost-michelin-inspection-and-stars/2016/05/27/fc1db658-2132-11e6-8690-f14ca9de2972_story.html,
# there are only three other Michelin-reviewed cities in the US: Chicago, NY and San Francisco.
#
#
# This student used yelp reviews to predict Michelin stars in SF: http://blog.nycdatascience.com/student-works/predicting-michelin-stars-yelp-reviews-san-francisco/
#
# Directions on scraping to not get banned: http://www.markbartlett.org/web-engineering/web-engineering-1/page-scraping-with-urllib2-beautifulsoup

# %%
import pandas as pd
import json

# %%
#start of my webscraping - trying page 1 of NYC: 
import urllib
from bs4 import BeautifulSoup

#initially I tried scraping the website you see in your browser...turns out to iterate through multiple pages must go to
#inspect, network, XHR
url="https://www.zagat.com/proxy/v1.4?kft=461&vertical=46&orderby=score_food&sort=desc&page=2&city=1020&query=&key=abbc09b7c840c10937a4db331422c98b&mobile_only_content=false&limit=15&m=filter&a=place"
html = urllib.urlopen(url).read()
soup = BeautifulSoup(html,"html.parser")

# %%
#print soup.prettify...because this is JSON, not very pretty!!
print soup.prettify()
# Out:
# {"success":true,"data":[{"addr_city":"New York","city":{"id":"1020","title":"New York City","slug":"new-york-city","avail_filters":["neighborhood"]},"closed":false,"cost":76,"cuisine":"French","currency_symbol":"$","date_opened":null,"feature_id":"0x89c258f66d739287:0x667798011a76e1cd","hours":[["11:45am - 11:00pm"],["11:45am - 11:00pm"],["11:45am - 11:00pm"],["11:45am - 11:00pm"],["11:45am - 11:00pm"],["11:45am - 11:00pm"],["11:45am - 11:00pm"]],"id":"676172","latitude":"40.7690697","longitude":"-73.9815598","neighborhood":"West 60s","obj_type":"place","open_now":false,"open_table":"http:\/\/www.opentable.com\/restaurant\/profile\/108982?ref=5305","partners":[],"photo":"http:\/\/storage.googleapis.com\/zgt-photos\/0x89c258f66d739287_0x667798011a76e1cd\/f8e54cb11d57ce0be67851570f95e591.jpg","photo_map":"http:\/\/maps.googleapis.com\/maps\/api\/staticmap?center=40.7690697,-73.9815598&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false","price_level":"E","redirect_url":null,"renamed":false,"score":{"overall":"0","food":"27","decor":"23","service":"26","appeal":"0","atmosphere":"0","quality":"0","facilities":"0","average":"25","score5_food":4.7,"score5_decor":4.3,"score5_service":4.6,"score5_atmosphere":0},"scores":["-","27","23","26","-","-","-","-"],"slug":"nougatine-at-jean-georges-new-york1","timezone":"America\/New_York","title":"Nougatine At Jean-Georges","url":"https:\/\/www.zagat.com\/r\/nougatine-at-jean-georges-new-york1","vertical":"Restaurants","vertical_id":322},{"addr_city":"New York","city":{"id":"1020","title":"New York City","slug":"new-york-city","avail_filters":["neighborhood"]},"closed":false,"cost":101,"cuisine":"European","currency_symbol":"$","date_opened":null,"feature_id":"0x89c2598aba875b73:0xdf096bf90b2a6d78","hours":[[],["5:30pm - 10:00pm"],["5:30pm - 10:00pm"],["5:30pm - 10:30pm"],["5:30pm - 10:30pm"],["5:30pm - 10:30pm"],["5:30pm - 10:30pm"]],"id":"681811","latitude":"40.7195587","longitude":"-74.0057526","neighborhood":"TriBeCa","obj_type":"place","open_now":false,"open_table":"http:\/\/www.opentable.com\/restaurant\/profile\/24382?ref=5305","partners":[],"photo":"http:\/\/storage.googleapis.com\/zgt-photos\/0x89c2598ab06255e5_0x1d0a6d4a4f287af2\/14869c20618913a14328906b3ee8df25.jpg","photo_map":"http:\/\/maps.googleapis.com\/maps\/api\/staticmap?center=40.7195587,-74.0057526&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false","price_level":"E","redirect_url":null,"renamed":false,"score":{"overall":"0","food":"27","decor":"22","service":"24","appeal":"0","atmosphere":"0","quality":"0","facilities":"0","average":"24","score5_food":4.7,"score5_decor":4.2,"score5_service":4.4,"score5_atmosphere":0},"scores":["-","27","22","24","-","-","-","-"],"slug":"batard-new-york","timezone":"America\/New_York","title":"B\u00e2tard","url":"https:\/\/www.zagat.com\/r\/batard-new-york","vertical":"Restaurants","vertical_id":322},{"addr_city":"New York","city":{"id":"1020","title":"New York City","slug":"new-york-city","avail_filters":["neighborhood"]},"closed":false,"cost":78,"cuisine":"Japanese","currency_symbol":"$","date_opened":null,"feature_id":"0x89c259852c3bac19:0xe6b01ca116d1fd0f","hours":[[],[],[],[],[],[],[]],"id":"633521","latitude":"40.7264061","longitude":"-73.9923630","neighborhood":"NoHo","obj_type":"place","open_now":false,"open_table":"","partners":[],"photo":"http:\/\/storage.googleapis.com\/zgt-photos\/0x89c259852c3bac19_0xe6b01ca116d1fd0f\/d236f7012f0622166d5739bae5f7f563.JPG","photo_map":"http:\/\/maps.googleapis.com\/maps\/api\/staticmap?center=40.7264061,-73.9923630&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false","price_level":"E","redirect_url":null,"renamed":false,"score":{"overall":"25","food":"27","decor":"24","service":"25","appeal":"0","atmosphere":"0","quality":"0","facilities":"0","average":"25","score5_food":4.7,"score5_decor":4.4,"score5_service":4.5,"score5_atmosphere":0},"scores":["25","27","24","25","-","-","-","-"],"slug":"bohemian-new-york","timezone":"America\/New_York","title":"Bo ...

# %%
# Loading the json
ny=json.loads(str(soup))

# %%
# Dictionary format
ny
# Out:
# {u'count': 985,
#  u'data': [{u'addr_city': u'New York',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 76,
#    u'cuisine': u'French',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c258f66d739287:0x667798011a76e1cd',
#    u'hours': [[u'11:45am - 11:00pm'],
#     [u'11:45am - 11:00pm'],
#     [u'11:45am - 11:00pm'],
#     [u'11:45am - 11:00pm'],
#     [u'11:45am - 11:00pm'],
#     [u'11:45am - 11:00pm'],
#     [u'11:45am - 11:00pm']],
#    u'id': u'676172',
#    u'latitude': u'40.7690697',
#    u'longitude': u'-73.9815598',
#    u'neighborhood': u'West 60s',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'http://www.opentable.com/restaurant/profile/108982?ref=5305',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c258f66d739287_0x667798011a76e1cd/f8e54cb11d57ce0be67851570f95e591.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7690697,-73.9815598&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'E',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'25',
#     u'decor': u'23',
#     u'facilities': u'0',
#     u'food': u'27',
#     u'overall': u'0',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 4.3,
#     u'score5_food': 4.7,
#     u'score5_service': 4.6,
#     u'service': u'26'},
#    u'scores': [u'-', u'27', u'23', u'26', u'-', u'-', u'-', u'-'],
#    u'slug': u'nougatine-at-jean-georges-new-york1',
#    u'timezone': u'America/New_York',
#    u'title': u'Nougatine At Jean-Georges',
#    u'url': u'https://www.zagat.com/r/nougatine-at-jean-georges-new-york1',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'New York',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 101,
#    u'cuisine': u'European',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c2598aba875b73:0xdf096bf90b2a6d78',
#    u'hours': [[],
#     [u'5:30pm - 10:00pm'],
#     [u'5:30pm - 10:00pm'],
#     [u'5:30pm - 10:30pm'],
#     [u'5:30pm - 10:30pm'],
#     [u'5:30pm - 10:30pm'],
#     [u'5:30pm - 10:30pm']],
#    u'id': u'681811',
#    u'latitude': u'40.7195587',
#    u'longitude': u'-74.0057526',
#    u'neighborhood': u'TriBeCa',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'http://www.opentable.com/restaurant/profile/24382?ref=5305',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c2598ab06255e5_0x1d0a6d4a4f287af2/14869c20618913a14328906b3ee8df25.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7195587,-74.0057526&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'E',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'24',
#     u'decor': u'22',
#     u'facilities': u'0',
#     u'food': u'27',
#     u'overall': u'0',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 4.2,
#     u'score5_food': 4.7,
#     u'score5_service': 4.4,
#     u'service': u'24'},
#    u'scores': [u'-', u'27', u'22', u'24', u'-', u'-', u'-', u'-'],
#    u'slug': u'batard-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u'B\xe2tard',
#    u'url': u'https://www.zagat.com/r/batard-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'New York',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 78,
#    u'cuisine': u'Japanese',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c259852c3bac19:0xe6b01ca116d1fd0f',
#    u'hours': [[], [], [], [], [], [], []],
#    u'id': u'633521',
#    u'latitude': u'40.7264061',
#    u'longitude': u'-73.9923630',
#    u'neighborhood': u'NoHo',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c259852c3bac19_0xe6b01ca116d1fd0f/d236f7012f0622166d5739bae5f7f563.JPG',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7264061,-73.9923630&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'E',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'25',
#     u'decor': u'24',
#     u'facilities': u'0',
#     u'food': u'27',
#     u'overall': u'25',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 4.4,
#     u'score5_food': 4.7,
#     u'score5_service': 4.5,
#     u'service': u'25'},
#    u'scores': [u'25', u'27', u'24', u'25', u'-', u'-', u'-', u'-'],
#    u'slug': u'bohemian-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u'Bohemian',
#    u'url': u'https://www.zagat.com/r/bohemian-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'New York',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 114,
#    u'cuisine': u'Japanese',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c2599877e795e7:0x5d33fe3d94c97710',
#    u'hours': [[],
#     [u'12:00pm - 1:45pm', u'6:00pm - 10:30pm'],
#     [u'12:00pm - 1:45pm', u'6:00pm - 10:30pm'],
#     [u'12:00pm - 1:45pm', u'6:00pm - 10:30pm'],
#     [u'12:00pm - 1:45pm', u'6:00pm - 10:30pm'],
#     [u'12:00pm - 1:45pm', u'6:00pm - 10:30pm'],
#     [u'12:00pm - 1:45pm', u'6:00pm - 11:00pm']],
#    u'id': u'607146',
#    u'latitude': u'40.7364082',
#    u'longitude': u'-73.9921875',
#    u'neighborhood': u'Union Square',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'http://www.opentable.com/restaurant/profile/24433?ref=5305',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c2599877e795e7_0x5d33fe3d94c97710/23cc604764924ef0b05060e651572d9a.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7364082,-73.9921875&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'E',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'24',
#     u'decor': u'22',
#     u'facilities': u'0',
#     u'food': u'27',
#     u'overall': u'23',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 4.2,
#     u'score5_food': 4.7,
#     u'score5_service': 4.4,
#     u'service': u'24'},
#    u'scores': [u'23', u'27', u'22', u'24', u'-', u'-', u'-', u'-'],
#    u'slug': u'15-east-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u'15 East',
#    u'url': u'https://www.zagat.com/r/15-east-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'Brooklyn',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 254,
#    u'cuisine': u'New American',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c25c00e9e428ad:0x7eadb4db7a975d27',
#    u'hours': [[], [], [], [], [], [], []],
#    u'id': u'605005',
#    u'latitude': u'40.7050629',
#    u'longitude': u'-73.9335861',
#    u'neighborhood': u'Bushwick',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c25c00e9e428ad_0x7eadb4db7a975d27/5d656056a1acef5e2a24993e2034af6a.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7050629,-73.9335861&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'VE',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'24',
#     u'decor': u'21',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'25',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 4.1,
#     u'score5_food': 4.6,
#     u'score5_service': 4.5,
#     u'service': u'25'},
#    u'scores': [u'25', u'26', u'21', u'25', u'-', u'-', u'-', u'-'],
#    u'slug': u'blanca-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u'Blanca',
#    u'url': u'https://www.zagat.com/r/blanca-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'Corona',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 6,
#    u'cuisine': u'Ice Cream Shop',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c25fce40809da1:0x5c9d0a4616003c42',
#    u'hours': [[u'10:00am - 12:00am'],
#     [u'10:00am - 12:00am'],
#     [u'10:00am - 12:00am'],
#     [u'10:00am - 12:00am'],
#     [u'10:00am - 12:00am'],
#     [u'10:00am - 12:00am'],
#     [u'10:00am - 12:00am']],
#    u'id': u'667699',
#    u'latitude': u'40.7431717',
#    u'longitude': u'-73.8550644',
#    u'neighborhood': u'Corona',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c25fce40809da1_0x5c9d0a4616003c42/4006066def94a3f58af477bf50bf0a07.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7431717,-73.8550644&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'I',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'16',
#     u'decor': u'7',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'21',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 2.7,
#     u'score5_food': 4.6,
#     u'score5_service': 3.7,
#     u'service': u'17'},
#    u'scores': [u'21', u'26', u'7', u'17', u'-', u'-', u'-', u'-'],
#    u'slug': u'the-lemon-ice-king-of-corona-queens',
#    u'timezone': u'America/New_York',
#    u'title': u'The Lemon Ice King of Corona',
#    u'url': u'https://www.zagat.com/r/the-lemon-ice-king-of-corona-queens',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'Long Island City',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 36,
#    u'cuisine': u'Japanese',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c25924f281531d:0x858b136f809aa515',
#    u'hours': [[u'5:00pm - 9:30pm'],
#     [u'12:00pm - 2:30pm', u'5:30pm - 10:00pm'],
#     [u'12:00pm - 2:30pm', u'5:30pm - 10:00pm'],
#     [u'12:00pm - 2:30pm', u'5:30pm - 10:00pm'],
#     [u'12:00pm - 2:30pm', u'5:30pm - 10:00pm'],
#     [u'12:00pm - 2:30pm', u'5:30pm - 10:30pm'],
#     [u'5:30pm - 10:30pm']],
#    u'id': u'677181',
#    u'latitude': u'40.7426376',
#    u'longitude': u'-73.9520264',
#    u'neighborhood': u'Long Island City',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c25924f281531d_0x858b136f809aa515/000c85cb657a41253049c20c6b6dca95.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7426376,-73.9520264&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'M',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'22',
#     u'decor': u'19',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'0',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 3.9,
#     u'score5_food': 4.6,
#     u'score5_service': 4.2,
#     u'service': u'22'},
#    u'scores': [u'-', u'26', u'19', u'22', u'-', u'-', u'-', u'-'],
#    u'slug': u'hibino',
#    u'timezone': u'America/New_York',
#    u'title': u'Hibino LIC',
#    u'url': u'https://www.zagat.com/r/hibino',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'Brooklyn',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 34,
#    u'cuisine': u'American',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c25c00e71cb3f3:0xa1a529cc35093e02',
#    u'hours': [[u'10:00am - 12:00am'],
#     [u'11:00am - 12:00am'],
#     [u'11:00am - 12:00am'],
#     [u'11:00am - 12:00am'],
#     [u'11:00am - 12:00am'],
#     [u'11:00am - 12:00am'],
#     [u'10:00am - 12:00am']],
#    u'id': u'623499',
#    u'latitude': u'40.7050781',
#    u'longitude': u'-73.9335938',
#    u'neighborhood': u'Bushwick',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c25c00e71cb3f3_0xa1a529cc35093e02/7091f3a04709340af7b8d161d7da49a8.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7050781,-73.9335938&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'M',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'21',
#     u'decor': u'19',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'21',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 3.9,
#     u'score5_food': 4.6,
#     u'score5_service': 3.9,
#     u'service': u'19'},
#    u'scores': [u'21', u'26', u'19', u'19', u'-', u'-', u'-', u'-'],
#    u'slug': u'robertas-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u"Roberta's",
#    u'url': u'https://www.zagat.com/r/robertas-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'Brooklyn',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 78,
#    u'cuisine': u'American',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c25a50c443e4cf:0x4adf1819e024630',
#    u'hours': [[u'5:30pm - 10:00pm'],
#     [u'5:30pm - 11:00pm'],
#     [u'5:30pm - 11:00pm'],
#     [u'5:30pm - 11:00pm'],
#     [u'5:30pm - 11:00pm'],
#     [u'5:30pm - 11:00pm'],
#     [u'5:30pm - 11:00pm']],
#    u'id': u'636093',
#    u'latitude': u'40.6831207',
#    u'longitude': u'-73.9926605',
#    u'neighborhood': u'Boerum Hill',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'http://www.opentable.com/restaurant/profile/152311?ref=5305',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c25a50c443e4cf_0x4adf1819e024630/5e68986917efc464e63d7f0f12b599bf.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.6831207,-73.9926605&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'E',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'23',
#     u'decor': u'19',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'24',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 3.9,
#     u'score5_food': 4.6,
#     u'score5_service': 4.5,
#     u'service': u'25'},
#    u'scores': [u'24', u'26', u'19', u'25', u'-', u'-', u'-', u'-'],
#    u'slug': u'battersby-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u'Battersby',
#    u'url': u'https://www.zagat.com/r/battersby-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'Brooklyn',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 37,
#    u'cuisine': u'Japanese Izakaya',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c25ba45a575805:0x390db092675c3489',
#    u'hours': [[u'5:30pm - 10:00pm'],
#     [],
#     [u'5:30pm - 10:00pm'],
#     [u'5:30pm - 10:00pm'],
#     [u'5:30pm - 11:00pm'],
#     [u'5:30pm - 11:00pm'],
#     [u'5:30pm - 11:00pm']],
#    u'id': u'683291',
#    u'latitude': u'40.6807747',
#    u'longitude': u'-73.9674377',
#    u'neighborhood': u'Prospect Heights',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'http://www.opentable.com/restaurant/profile/191626?ref=5305',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c25ba45a575805_0x390db092675c3489/5ec50ffd81de30a6101738ef550ceff6.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.6807747,-73.9674377&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'I',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'23',
#     u'decor': u'21',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'0',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 4.1,
#     u'score5_food': 4.6,
#     u'score5_service': 4.3,
#     u'service': u'23'},
#    u'scores': [u'-', u'26', u'21', u'23', u'-', u'-', u'-', u'-'],
#    u'slug': u'bar-chuko',
#    u'timezone': u'America/New_York',
#    u'title': u'Bar Chuko Izakaya',
#    u'url': u'https://www.zagat.com/r/bar-chuko',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'New York',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 93,
#    u'cuisine': u'Japanese',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c258e809a826d3:0xa6c8c534ca342e95',
#    u'hours': [[],
#     [u'5:30pm - 2:30am'],
#     [u'5:30pm - 2:30am'],
#     [u'5:30pm - 2:30am'],
#     [u'5:30pm - 2:30am'],
#     [u'5:30pm - 2:30am'],
#     [u'5:30pm - 2:30am']],
#    u'id': u'616615',
#    u'latitude': u'40.7619171',
#    u'longitude': u'-73.9605331',
#    u'neighborhood': u'East 60s',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c258e809a826d3_0xa6c8c534ca342e95/ecae88513125b7cec8d7e5e514074d6a.JPG',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7619171,-73.9605331&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'VE',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'20',
#     u'decor': u'15',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'20',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 3.5,
#     u'score5_food': 4.6,
#     u'score5_service': 4,
#     u'service': u'20'},
#    u'scores': [u'20', u'26', u'15', u'20', u'-', u'-', u'-', u'-'],
#    u'slug': u'sushi-seki-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u'Sushi Seki Upper East',
#    u'url': u'https://www.zagat.com/r/sushi-seki-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'New York',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 88,
#    u'cuisine': u'Steakhouse',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c259ab55823ab9:0xdfc36ec4ce37a569',
#    u'hours': [[u'12:00pm - 11:00pm'],
#     [u'12:00pm - 11:00pm'],
#     [u'12:00pm - 11:00pm'],
#     [u'12:00pm - 11:00pm'],
#     [u'12:00pm - 11:00pm'],
#     [u'12:00pm - 12:00am'],
#     [u'12:00pm - 12:00am']],
#    u'id': u'629214',
#    u'latitude': u'40.7558212',
#    u'longitude': u'-73.9894562',
#    u'neighborhood': u'West 40s',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'http://www.opentable.com/restaurant/profile/75409?ref=5305',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c259ab55823ab9_0xdfc36ec4ce37a569/6a20782668c1d450daf497593254ebe4.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7558212,-73.9894562&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'VE',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'23',
#     u'decor': u'21',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'23',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 4.1,
#     u'score5_food': 4.6,
#     u'score5_service': 4.3,
#     u'service': u'23'},
#    u'scores': [u'23', u'26', u'21', u'23', u'-', u'-', u'-', u'-'],
#    u'slug': u'wolfgangs-steakhouse-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u"Wolfgang's Steakhouse",
#    u'url': u'https://www.zagat.com/r/wolfgangs-steakhouse-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'Astoria',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 21,
#    u'cuisine': u'Italian',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c25f3905f2cbcb:0x514def9668011488',
#    u'hours': [[u'10:00am - 10:00pm'],
#     [u'10:30am - 10:30pm'],
#     [u'10:30am - 10:30pm'],
#     [u'10:30am - 10:30pm'],
#     [u'10:30am - 10:30pm'],
#     [u'10:30am - 11:00pm'],
#     [u'10:00am - 11:00pm']],
#    u'id': u'642925',
#    u'latitude': u'40.7628593',
#    u'longitude': u'-73.9208908',
#    u'neighborhood': u'Astoria',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c25f3905f2cbcb_0x514def9668011488/c6eb433d1cd899b26572e38b8e8cd28a.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7628593,-73.9208908&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'M',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'22',
#     u'decor': u'18',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'23',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 3.8,
#     u'score5_food': 4.6,
#     u'score5_service': 4.2,
#     u'service': u'22'},
#    u'scores': [u'23', u'26', u'18', u'22', u'-', u'-', u'-', u'-'],
#    u'slug': u'il-bambino-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u'IL Bambino',
#    u'url': u'https://www.zagat.com/r/il-bambino-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'Brooklyn',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 32,
#    u'cuisine': u'Barbecue',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c2595f0064ede7:0x9f203ffd6fec2fc7',
#    u'hours': [[u'12:00pm - 11:00pm'],
#     [u'5:00pm - 11:00pm'],
#     [u'5:00pm - 11:00pm'],
#     [u'5:00pm - 11:00pm'],
#     [u'12:00pm - 11:00pm'],
#     [u'12:00pm - 2:00am'],
#     [u'12:00pm - 2:00am']],
#    u'id': u'638203',
#    u'latitude': u'40.7138824',
#    u'longitude': u'-73.9564743',
#    u'neighborhood': u'Williamsburg',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c2595f0064ede7_0x9f203ffd6fec2fc7/f08e95799045fd4503886cde44c3e0bb.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7138824,-73.9564743&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'M',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'20',
#     u'decor': u'18',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'21',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 3.8,
#     u'score5_food': 4.6,
#     u'score5_service': 3.7,
#     u'service': u'17'},
#    u'scores': [u'21', u'26', u'18', u'17', u'-', u'-', u'-', u'-'],
#    u'slug': u'fette-sau-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u'Fette Sau',
#    u'url': u'https://www.zagat.com/r/fette-sau-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322},
#   {u'addr_city': u'New York',
#    u'city': {u'avail_filters': [u'neighborhood'],
#     u'id': u'1020',
#     u'slug': u'new-york-city',
#     u'title': u'New York City'},
#    u'closed': False,
#    u'cost': 88,
#    u'cuisine': u'Steakhouse',
#    u'currency_symbol': u'$',
#    u'date_opened': None,
#    u'feature_id': u'0x89c2590793d5e1cb:0xd689287d3cdf4955',
#    u'hours': [[u'12:00pm - 10:30pm'],
#     [u'12:00pm - 10:30pm'],
#     [u'12:00pm - 10:30pm'],
#     [u'12:00pm - 10:30pm'],
#     [u'12:00pm - 10:30pm'],
#     [u'12:00pm - 11:30pm'],
#     [u'12:00pm - 11:30pm']],
#    u'id': u'634410',
#    u'latitude': u'40.7466202',
#    u'longitude': u'-73.9819717',
#    u'neighborhood': u'Murray Hill',
#    u'obj_type': u'place',
#    u'open_now': False,
#    u'open_table': u'http://www.opentable.com/restaurant/profile/3603?ref=5305',
#    u'partners': [],
#    u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c2590793d5e1cb_0xd689287d3cdf4955/fd6340eec906ef640f5bee6ee327b9da.jpg',
#    u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7466202,-73.9819717&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#    u'price_level': u'VE',
#    u'redirect_url': None,
#    u'renamed': False,
#    u'score': {u'appeal': u'0',
#     u'atmosphere': u'0',
#     u'average': u'23',
#     u'decor': u'21',
#     u'facilities': u'0',
#     u'food': u'26',
#     u'overall': u'22',
#     u'quality': u'0',
#     u'score5_atmosphere': 0,
#     u'score5_decor': 4.1,
#     u'score5_food': 4.6,
#     u'score5_service': 4.3,
#     u'service': u'23'},
#    u'scores': [u'22', u'26', u'21', u'23', u'-', u'-', u'-', u'-'],
#    u'slug': u'wolfgangs-steakhouse-at-park-avenue-new-york',
#    u'timezone': u'America/New_York',
#    u'title': u"Wolfgang's Steakhouse Park Avenue",
#    u'url': u'https://www.zagat.com/r/wolfgangs-steakhouse-at-park-avenue-new-york',
#    u'vertical': u'Restaurants',
#    u'vertical_id': 322}],
#  u'is_elasticsearch': True,
#  u'refinements': {u'cities': {u'Attractions': [],
#    u'Hotels': [],
#    u'Nightlife': [],
#    u'Restaurants': [{u'count': 12, u'id': u'Astoria', u'name': u'Astoria'},
#     {u'count': 4, u'id': u'Bayside', u'name': u'Bayside'},
#     {u'count': 17, u'id': u'Bronx', u'name': u'Bronx'},
#     {u'count': 172, u'id': u'Brooklyn', u'name': u'Brooklyn'},
#     {u'count': 3, u'id': u'Corona', u'name': u'Corona'},
#     {u'count': 1, u'id': u'East Elmhurst', u'name': u'East Elmhurst'},
#     {u'count': 1, u'id': u'Elmhurst', u'name': u'Elmhurst'},
#     {u'count': 2, u'id': u'Floral Park', u'name': u'Floral Park'},
#     {u'count': 1, u'id': u'New Zealand', u'name': u'New Zealand'},
#     {u'count': 1, u'id': u'Noodle Shop', u'name': u'Noodle Shop'},
#     {u'count': 2, u'id': u'Nuevo Latino', u'name': u'Nuevo Latino'},
#     {u'count': 3, u'id': u'Organic', u'name': u'Organic'},
#     {u'count': 2, u'id': u'Oyster Bar', u'name': u'Oyster Bar'},
#     {u'count': 1, u'id': u'Persian', u'name': u'Persian'},
#     {u'count': 7, u'id': u'Peruvian', u'name': u'Peruvian'},
#     {u'count': 1, u'id': u'Pho', u'name': u'Pho'},
#     {u'count': 35, u'id': u'Pizza', u'name': u'Pizza'},
#     {u'count': 1, u'id': u'Portuguese', u'name': u'Portuguese'},
#     {u'count': 1, u'id': u'Puerto Rican', u'name': u'Puerto Rican'},
#     {u'count': 7, u'id': u'Ramen', u'name': u'Ramen'},
#     {u'count': 1, u'id': u'Russian', u'name': u'Russian'},
#     {u'count': 20, u'id': u'Sandwich Shop', u'name': u'Sandwich Shop'},
#     {u'count': 1, u'id': u'Scandinavian', u'name': u'Scandinavian'},
#     {u'count': 32, u'id': u'Seafood', u'name': u'Seafood'},
#     {u'count': 1, u'id': u'Serbian', u'name': u'Serbian'},
#     {u'count': 1, u'id': u'Soul Food', u'name': u'Soul Food'},
#     {u'count': 5, u'id': u'Southern American', u'name': u'Southern American'},
#     {u'count': 1, u'id': u'Southern Italian', u'name': u'Southern Italian'},
#     {u'count': 16, u'id': u'Spanish', u'name': u'Spanish'},
#     {u'count': 37, u'id': u'Steakhouse', u'name': u'Steakhouse'},
#     {u'count': 13, u'id': u'Sushi', u'name': u'Sushi'},
#     {u'count': 1, u'id': u'Tapas Bar', u'name': u'Tapas Bar'},
#     {u'count': 4, u'id': u'Tea House', u'name': u'Tea House'},
#     {u'count': 14, u'id': u'Thai', u'name': u'Thai'},
#     {u'count': 4, u'id': u'Turkish', u'name': u'Turkish'},
#     {u'count': 7, u'id': u'Vegan', u'name': u'Vegan'},
#     {u'count': 3, u'id': u'Vegetarian', u'name': u'Vegetarian'},
#     {u'count': 4, u'id': u'Venezuelan', u'name': u'Venezuelan'},
#     {u'count': 5, u'id': u'Vietnamese', u'name': u'Vietnamese'}],
#    u'Shopping': []},
#   u'verticals': [{u'count': 3, u'id': 45, u'name': u'Nightlife'},
#    {u'count': 985, u'id': 46, u'name': u'Restaurants'}]},
#  u'success': True}

# %%
#looking at keys -- 'data' is the one I'm interested in
list(ny.keys())
# Out:
# [u'count', u'refinements', u'is_elasticsearch', u'data', u'success']

# %%
# Taking a look at the first row  0 in data, I can see that zagat score is included as sub-dictionary 
# (its also entertaining to notice the old 30-point scores still in there!)
ny['data'][0]
# Out:
# {u'addr_city': u'New York',
#  u'city': {u'avail_filters': [u'neighborhood'],
#   u'id': u'1020',
#   u'slug': u'new-york-city',
#   u'title': u'New York City'},
#  u'closed': False,
#  u'cost': 76,
#  u'cuisine': u'French',
#  u'currency_symbol': u'$',
#  u'date_opened': None,
#  u'feature_id': u'0x89c258f66d739287:0x667798011a76e1cd',
#  u'hours': [[u'11:45am - 11:00pm'],
#   [u'11:45am - 11:00pm'],
#   [u'11:45am - 11:00pm'],
#   [u'11:45am - 11:00pm'],
#   [u'11:45am - 11:00pm'],
#   [u'11:45am - 11:00pm'],
#   [u'11:45am - 11:00pm']],
#  u'id': u'676172',
#  u'latitude': u'40.7690697',
#  u'longitude': u'-73.9815598',
#  u'neighborhood': u'West 60s',
#  u'obj_type': u'place',
#  u'open_now': False,
#  u'open_table': u'http://www.opentable.com/restaurant/profile/108982?ref=5305',
#  u'partners': [],
#  u'photo': u'http://storage.googleapis.com/zgt-photos/0x89c258f66d739287_0x667798011a76e1cd/f8e54cb11d57ce0be67851570f95e591.jpg',
#  u'photo_map': u'http://maps.googleapis.com/maps/api/staticmap?center=40.7690697,-73.9815598&amp;zoom;=14&amp;size;=200x200&amp;sensor;=false',
#  u'price_level': u'E',
#  u'redirect_url': None,
#  u'renamed': False,
#  u'score': {u'appeal': u'0',
#   u'atmosphere': u'0',
#   u'average': u'25',
#   u'decor': u'23',
#   u'facilities': u'0',
#   u'food': u'27',
#   u'overall': u'0',
#   u'quality': u'0',
#   u'score5_atmosphere': 0,
#   u'score5_decor': 4.3,
#   u'score5_food': 4.7,
#   u'score5_service': 4.6,
#   u'service': u'26'},
#  u'scores': [u'-', u'27', u'23', u'26', u'-', u'-', u'-', u'-'],
#  u'slug': u'nougatine-at-jean-georges-new-york1',
#  u'timezone': u'America/New_York',
#  u'title': u'Nougatine At Jean-Georges',
#  u'url': u'https://www.zagat.com/r/nougatine-at-jean-georges-new-york1',
#  u'vertical': u'Restaurants',
#  u'vertical_id': 322}

# %%
# This syntax will pull just the 5-point food score from row 0
ny['data'][0]['score']['score5_food']
# Out:
# 4.7

# %%
nyc = pd.DataFrame()

# %%
#now that I've looked at the data, I want to iterate over pages to pull variables into a dataframe pages 1-186
for i in range(150, 186):
    url="https://www.zagat.com/proxy/v1.4?vertical=46&orderby=score_food&sort=desc&page=%d&city=1020&query=&key=abbc09b7c840c10937a4db331422c98b&mobile_only_content=false&limit=15&m=filter&a=place" %(i)
    html = urllib.urlopen(url).read()
    soup = BeautifulSoup(html,"html.parser")
    ny=json.loads(str(soup))
    nyadd = pd.DataFrame(ny["data"])
    food = pd.DataFrame()
    decor = pd.DataFrame()
    service = pd.DataFrame()
    for j in range (0,len(ny["data"])):
        food = food.append(pd.Series(ny['data'][j]['score']['score5_food']),ignore_index=True)
        decor = decor.append(pd.Series(ny['data'][j]['score']['score5_decor']),ignore_index=True)
        service = service.append(pd.Series(ny['data'][j]['score']['score5_service']),ignore_index=True)
    nyadd['food'] = food
    nyadd['decor'] = decor
    nyadd['service'] = service
    nyc = nyc.append(nyadd)      
nyc = nyc.reset_index()
del nyc['index']

# %%
nyc.shape
# Out:
# (2770, 33)

# %%
# A few spot check comparisons to the website
vars = ['title','food', 'decor', 'service']
nyc[vars][nyc.title.str.contains('(Lemon Ice)')]
# Out:
# C:\Users\elynchklarup\AppData\Local\Continuum\Anaconda2_take2\lib\site-packages\ipykernel\__main__.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()
#                            title  food  decor  service
# 56  The Lemon Ice King of Corona   4.6    2.7      3.7

# %%
#Now that I have my NYC Zagat data, I'm going to save. Saving as raw1 -- I may pull again, merge, drop duplicates.
nyc.to_pickle('../nyc_raw2.pkl') 

#When I want to read this in, I'll just read in: new_file_name = pd.read_pickle('../nyc_zagat.pkl')

# %%
#And now, to get the San Francisco and Chicago data, I'll repeat these steps... 
chicago = pd.DataFrame()

# %%
#Chicago - 1376 restaurants, pages 1-93
for i in range(50, 93):
    url= "https://www.zagat.com/proxy/v1.4?vertical=46&orderby=score_food&sort=desc&page=%d&city=1013&query=&key=abbc09b7c840c10937a4db331422c98b&mobile_only_content=false&limit=15&m=filter&a=place" %(i)
    html = urllib.urlopen(url).read()
    soup = BeautifulSoup(html,"html.parser")
    city=json.loads(str(soup))
    cityadd = pd.DataFrame(city["data"])
    food = pd.DataFrame()
    decor = pd.DataFrame()
    service = pd.DataFrame()
    for j in range (0,len(city["data"])):
        food = food.append(pd.Series(city['data'][j]['score']['score5_food']),ignore_index=True)
        decor = decor.append(pd.Series(city['data'][j]['score']['score5_decor']),ignore_index=True)
        service = service.append(pd.Series(city['data'][j]['score']['score5_service']),ignore_index=True)
    cityadd['food'] = food
    cityadd['decor'] = decor
    cityadd['service'] = service
    chicago = chicago.append(cityadd) 
chicago = chicago.reset_index()
del chicago['index']

# %%
chicago.shape
# Out:
# (1376, 33)

# %%
# A few spot check comparisons to the website
vars = ['title','food', 'decor', 'service']
chicago[vars][chicago.title.str.contains('(Mercat)')]
# Out:
# C:\Users\elynchklarup\AppData\Local\Continuum\Anaconda2_take2\lib\site-packages\ipykernel\__main__.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()
#                      title  food  decor  service
# 49      Mercat a la Planxa   4.6    4.4      4.3
# 928                Mercato   0.0    0.0      0.0
# 1019  Pizzeria del Mercato   0.0    0.0      0.0

# %%
chicago.to_pickle('../chicago_raw1.pkl')

# %%
#DC - 1191 restaurants, 81 pages
dc = pd.DataFrame()

# %%
for i in range(1, 81):
    url="https://www.zagat.com/proxy/v1.4?vertical=46&orderby=score_food&sort=desc&page=%d&city=1024&query=&key=abbc09b7c840c10937a4db331422c98b&mobile_only_content=false&limit=15&m=filter&a=place" %(i)
    html = urllib.urlopen(url).read()
    soup = BeautifulSoup(html,"html.parser")
    city=json.loads(str(soup))
    cityadd = pd.DataFrame(city["data"])
    food = pd.DataFrame()
    decor = pd.DataFrame()
    service = pd.DataFrame()
    for j in range (0,len(city["data"])):
        food = food.append(pd.Series(city['data'][j]['score']['score5_food']),ignore_index=True)
        decor = decor.append(pd.Series(city['data'][j]['score']['score5_decor']),ignore_index=True)
        service = service.append(pd.Series(city['data'][j]['score']['score5_service']),ignore_index=True)
    cityadd['food'] = food
    cityadd['decor'] = decor
    cityadd['service'] = service
    dc = dc.append(cityadd) 

dc = dc.reset_index()
del dc['index']

# %%
dc.shape
# Out:
# (1197, 33)

# %%
dc.to_pickle('../dc_raw3.pkl')

# %%
# A few spot check comparisons to the website
vars = ['title','food', 'decor', 'service', 'neighborhood']
dc[vars][dc.title.str.contains('(Lost Dog)')]
# Out:
# C:\Users\elynchklarup\AppData\Local\Continuum\Anaconda2_take2\lib\site-packages\ipykernel\__main__.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()
#                                  title  food  decor  service neighborhood
# 95                       Lost Dog Cafe   4.5    4.1      4.1         None
# 112                      Lost Dog Cafe   4.5    4.1      4.1         None
# 130                      Lost Dog Cafe   4.5    4.1      4.1         None
# 150                      Lost Dog Cafe   4.5    4.1      4.1         None
# 362  Lost Dog Cafe Old Town Alexandria   4.3    3.8      4.1         None

# %%
#DC proper - 688 restaurants
dc_prop = pd.DataFrame()

# %%
for i in range(1, 47):
    url="https://www.zagat.com/proxy/v1.4?addr_city=Washington&vertical=46&orderby=score_food&sort=desc&page=%d&city=1024&query=&key=abbc09b7c840c10937a4db331422c98b&mobile_only_content=false&limit=15&m=filter&a=place" %(i)
    html = urllib.urlopen(url).read()
    soup = BeautifulSoup(html,"html.parser")
    city=json.loads(str(soup))
    cityadd = pd.DataFrame(city["data"])
    food = pd.DataFrame()
    decor = pd.DataFrame()
    service = pd.DataFrame()
    for j in range (0,len(city["data"])):
        food = food.append(pd.Series(city['data'][j]['score']['score5_food']),ignore_index=True)
        decor = decor.append(pd.Series(city['data'][j]['score']['score5_decor']),ignore_index=True)
        service = service.append(pd.Series(city['data'][j]['score']['score5_service']),ignore_index=True)
    cityadd['food'] = food
    cityadd['decor'] = decor
    cityadd['service'] = service
    dc_prop = dc_prop.append(cityadd) 

dc_prop = dc_prop.reset_index()
del dc_prop['index']

# %%
dc_prop.shape
# Out:
# (690, 33)

# %%
# A few spot check comparisons to the website
vars = ['title','url', 'food', 'decor', 'service']
dc_prop[vars][dc_prop.title.str.contains('(Oohh)')]
# Out:
# C:\Users\elynchklarup\AppData\Local\Continuum\Anaconda2_take2\lib\site-packages\ipykernel\__main__.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()
#                    title                                             url  \
# 136  Oohh's &amp; Aahh's  https://www.zagat.com/r/oohhs-aahhs-washington
#
#      food  decor  service
# 136   4.4    2.8      3.8

# %%
dc_prop.to_pickle('../dc_prop_raw1.pkl')

# %%
sf = pd.DataFrame()

# %%
#SF - 2021 restaurants 1,136
for i in range(1, 50):
    url= "https://www.zagat.com/proxy/v1.4?vertical=46&orderby=score_food&sort=desc&page=%d&city=1021&query=&key=abbc09b7c840c10937a4db331422c98b&mobile_only_content=false&limit=15&m=filter&a=place" %(i)
    html = urllib.urlopen(url).read()
    soup = BeautifulSoup(html,"html.parser")
    city=json.loads(str(soup))
    cityadd = pd.DataFrame(city["data"])
    food = pd.DataFrame()
    decor = pd.DataFrame()
    service = pd.DataFrame()
    for j in range (0,len(city["data"])):
        food = food.append(pd.Series(city['data'][j]['score']['score5_food']),ignore_index=True)
        decor = decor.append(pd.Series(city['data'][j]['score']['score5_decor']),ignore_index=True)
        service = service.append(pd.Series(city['data'][j]['score']['score5_service']),ignore_index=True)
    cityadd['food'] = food
    cityadd['decor'] = decor
    cityadd['service'] = service
    sf = sf.append(cityadd) 

sf = sf.reset_index()
del sf['index']

# %%
sf.shape
# Out:
# (2023, 33)

# %%
sf.to_pickle('../sf_raw2.pkl')
