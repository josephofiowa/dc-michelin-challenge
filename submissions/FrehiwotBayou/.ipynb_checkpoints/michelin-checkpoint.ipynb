# %%
import numpy as np
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def get_access_token():
   response = requests.post('https://api.yelp.com/oauth2/token',
                           data={'grand_type': 'client_credentials',
                           'client_id': 'XXXXXXXXXXXXXXXXXXX',
                           'client_secret': 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'})
   return response.json()['access_token']

def get_search(loc,sor,pri,ter):
   access_token = get_access_token()
   base_url = "https://api.yelp.com/v3/businesses/search?"
   search_terms = "location=%s&categories=restaurants&sort_by=%s&price=%s&term=%s"
   response = requests.get(base_url + search_terms % (loc,sor,pri,ter),
                          headers={'Authorization': 'Bearer %s' % access_token})
   search_result = response.json()
   return search_result

# %%
cty=["San Francisco","Washington, dc","chicago","New York"]
rte=[4,3,2,]
list_rest=[]
for c in cty:
    for r in rte:
        restaurant = get_search(c, "rating", r,"michelin")
        for i,j in enumerate(restaurant['businesses']):
            r_dict={}
            r_dict['name']=restaurant['businesses'][i]['name']
            r_dict['rating']=restaurant['businesses'][i]['rating']
            r_dict['price']=restaurant['businesses'][i]['price']
            r_dict['review_count']=restaurant['businesses'][i]['review_count']
            r_dict['categories']=restaurant['businesses'][i]['categories']
            r_dict['id']=restaurant['businesses'][i]['id']
            r_dict['city']=restaurant['businesses'][i]['location']['city']
            list_rest.append(r_dict)
all_restaurant=pd.DataFrame(list_rest)

# %%
all_restaurant.shape
# Out:
# (196, 7)

# %%
all_restaurant.price=[len(x) for x in all_restaurant.price]

# %%
all_restaurant.categories= [x[0] for x in all_restaurant.categories]

# %%
all_restaurant.categories=[x['title'] for x in all_restaurant.categories]

# %%
all_restaurant.dtypes
# Out:
# categories       object
# city             object
# id               object
# name             object
# price             int64
# rating          float64
# review_count      int64
# dtype: object

# %%
all_restaurant.id =all_restaurant.id.str.encode('utf-8')
all_restaurant.name =all_restaurant.name.str.encode('utf-8')

# %%
all_restaurant
# Out:
#                  categories              city  \
# 0                Sushi Bars     San Francisco
# 1            American (New)     San Francisco
# 2                   Mexican     San Francisco
# 3                    French     San Francisco
# 4                   Italian     San Francisco
# 5            American (New)     San Francisco
# 6                Sushi Bars     San Francisco
# 7                  Japanese     San Francisco
# 8                    French     San Francisco
# 9            American (New)     San Francisco
# 10                   French     San Francisco
# 11           American (New)     San Francisco
# 12   American (Traditional)     San Francisco
# 13              Steakhouses     San Francisco
# 14                   French     San Francisco
# 15           American (New)     San Francisco
# 16                   French     San Francisco
# 17                   French     San Francisco
# 18           American (New)     San Francisco
# 19           American (New)     San Francisco
# 20                   French     San Francisco
# 21           American (New)     San Francisco
# 22       Tapas/Small Plates     San Francisco
# 23                   French     San Francisco
# 24                 Moroccan     San Francisco
# 25               Sushi Bars     San Francisco
# 26           American (New)     San Francisco
# 27           American (New)     San Francisco
# 28           American (New)     San Francisco
# 29                  Italian     San Francisco
# ..                      ...               ...
# 166                  French          New York
# 167                 Italian          New York
# 168                 Lounges          New York
# 169                  Indian          New York
# 170          American (New)          New York
# 171                  French          New York
# 172          American (New)          New York
# 173                    Thai          New York
# 174              Portuguese          New York
# 175                 British          New York
# 176                   Ramen          New York
# 177            Coffee & Tea          New York
# 178                 Mexican  Long Island City
# 193       0.0
# 194       0.0
# 195       0.0
#
# [196 rows x 8 columns]

# %%
all_restaurant.to_csv("yelpRestaurants.csv")

# %%
w_predict=all_restaurant[all_restaurant.city=="Washington"]
w_predict=all_restaurant[all_restaurant.Michelin!=0]
w_predict.shape
# Out:
# (69, 8)

# %%
w_predict[all_restaurant.Michelin.notnull()]
# Out:
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#                  categories              city  \
# 1            American (New)     San Francisco
# 2                   Mexican     San Francisco
# 4                   Italian     San Francisco
# 5            American (New)     San Francisco
# 6                Sushi Bars     San Francisco
# 8                    French     San Francisco
# 9            American (New)     San Francisco
# 10                   French     San Francisco
# 11           American (New)     San Francisco
# 12   American (Traditional)     San Francisco
# 14                   French     San Francisco
# 15           American (New)     San Francisco
# 19           American (New)     San Francisco
# 22       Tapas/Small Plates     San Francisco
# 28           American (New)     San Francisco
# 31           American (New)     San Francisco
# 32                  Italian     San Francisco
# 33           American (New)     San Francisco
# 34           American (New)     San Francisco
# 35           American (New)     San Francisco
# 36          Modern European     San Francisco
# 44                     Thai     San Francisco
# 98           American (New)           Chicago
# 100          American (New)           Chicago
# 101          American (New)           Chicago
# 105          American (New)           Chicago
# 106          American (New)           Chicago
# 108          American (New)           Chicago
# 111          American (New)           Chicago
# 112                 Italian           Chicago
# ..                      ...               ...
# 116          American (New)           Chicago
# 121          American (New)           Chicago
# 124          American (New)           Chicago
# 126                  Korean           Chicago
# 127          American (New)           Chicago
# 129                  Hotels           Chicago
# 136                  French          New York
# 137                  French          New York
# 138                  French          New York
# 139          American (New)          New York
# 140          American (New)          New York
# 141                  Korean          New York
# 142          American (New)          Brooklyn
# 144                  French          New York
# 145                  French          New York
# 146          American (New)          New York
# 147                Japanese          New York
# 149                    Bars          New York
# 150  American (Traditional)          New York
# 151          American (New)          New York
# 153                 Italian          New York
# 155          American (New)          New York
# 161          American (New)          New York
# 165                  French          New York
# 173                    Thai          New York
# 174              Portuguese          New York
# 178                 Mexican  Long Island City
# 179               Malaysian          New York
# 182                    Thai          New York
# 190                Szechuan          New York
#
#                                           id                           name  \
# 1                   gary-danko-san-francisco                     Gary Danko
# 2                  californios-san-francisco                    Californios
# 4                   acquerello-san-francisco                     Acquerello
# 5                       benu-san-francisco-4                           Benu
# 6                      omakase-san-francisco                        Omakase
# 8           keiko-à-nob-hill-san-francisco-2               Keiko à Nob Hill
# 9                  lazy-bear-san-francisco-5                      Lazy Bear
# 10               atelier-crenn-san-francisco                  Atelier Crenn
# 11                    saison-san-francisco-2                         Saison
# 12                      spruce-san-francisco                         Spruce
# 14                      quince-san-francisco                         Quince
# 15          sons-and-daughters-san-francisco               Sons & Daughters
# 19              michael-mina-san-francisco-2                   Michael Mina
# 22       state-bird-provisions-san-francisco          State Bird Provisions
# 28                     octavia-san-francisco                        Octavia
# 31                commonwealth-san-francisco                   Commonwealth
# 32                        spqr-san-francisco                           SPQR
# 33                       aster-san-francisco                          Aster
# 34                        nico-san-francisco                           Nico
# 35                        luce-san-francisco                           Luce
# 36                lord-stanley-san-francisco                   Lord Stanley
# 137      4     4.5          1215       3.0
# 138      4     4.5          1865       3.0
# 139      4     4.5          1553       3.0
# 140      4     4.5          2105       1.0
# 141      4     4.5           326       2.0
# 142      4     4.5           326       3.0
# 144      4     4.5          1040       1.0
# 145      4     4.5          1494       3.0
# 146      4     4.5          1263       1.0
# 147      4     4.5           376       1.0
# 149      4     4.5           134       1.0
# 150      4     4.5           164       2.0
# 151      4     4.5           767       1.0
# 153      4     4.0          1395       2.0
# 155      4     4.0           666       2.0
# 161      3     4.5           247       1.0
# 165      3     4.0          1719       1.0
# 173      3     4.0           378       1.0
# 174      3     4.0           488       1.0
# 178      2     4.0           603       1.0
# 179      2     4.0           361       1.0
# 182      2     4.0           407       1.0
# 190      2     3.5           654       1.0
#
# [62 rows x 8 columns]

# %%
all_restaurant.city.unique()
# Out:
# array([u'San Francisco', u'Sausalito', u'Washington', u'Annandale',
#        u'Chicago', u'New York', u'Brooklyn', u'Long Island City',
#        u'Astoria', u'Jackson Heights', u'Flushing'], dtype=object)

# %%
df=pd.read_csv('Mitchelin Restaurants.csv')
df=df.drop(["yelp_Average_rating","Unnamed: 5"],1)
df=df.rename(columns = {'City':'city', 'Restaurant':'name','Michelin_starrs':'Michelin_stars'})

# %%
df
# Out:
#               city                         name      neighborhood  \
# 0          Chicago                     42 Grams            Uptown
# 1          Chicago                       Acadia        South Loop
# 2          Chicago                       Alinea      Lincoln Park
# 3          Chicago                    Blackbird         West Loop
# 4          Chicago                         Boka      Lincoln Park
# 5          Chicago                      Dusek's            Pilsen
# 6          Chicago                     El Ideas      Douglas Park
# 7          Chicago                    Elizabeth        Ravenswood
# 8          Chicago                      Everest              Loop
# 9          Chicago                    Goosefoot        Ravenswood
# 10         Chicago                        Grace         West Loop
# 11         Chicago              Longman & Eagle      Logan Square
# 12         Chicago                         Moto     Fulton Market
# 13         Chicago                         NAHA       River North
# 14         Chicago                   North Pond      Lincoln Park
# 15         Chicago                    Parachute          Avondale
# 16         Chicago                        Schwa         West Town
# 17         Chicago                        Sepia         West Loop
# 18         Chicago                      Sixteen       River North
# 19         Chicago                     Spiaggia  Magnificent Mile
# 20         Chicago                  Topolobampo       River North
# 21         Chicago                          Tru     Streeterville
# 22   San Francisco                   Acquerello          Nob Hill
# 23   San Francisco                   Al's Place           Mission
# 24   San Francisco                    All Spice         San Mateo
# 25   San Francisco                          Ame              SoMa
# 26   San Francisco                        Aster           Mission
# 27   San Francisco                Atelier Crenn        Cow Hollow
# 28   San Francisco            Auberge du Soleil        Rutherford
# 29   San Francisco                        Aziza          Richmond
# ..             ...                          ...               ...
# 378  Washington DC                 Compass Rose               NaN
# 379  Washington DC                    Bar Pilar               NaN
# 380  Washington DC                    Convivial               NaN
# 381  Washington DC                   The Dabney               NaN
# 382  Washington DC                    The Royal               NaN
# 383  Washington DC                 Le Diplomate               NaN
# 384  Washington DC                      Estadio               NaN
# 385  Washington DC                 Little Serow               NaN
# 386  Washington DC                    Iron Gate               NaN
# 387  Washington DC                  Bombay Club               NaN
# 388  Washington DC            Espita Mezcaleria               NaN
# 389  Washington DC                    Del Campo               NaN
# 390  Washington DC                     Zaytinya               NaN
# 391  Washington DC                      Daikaya               NaN
# 392  Washington DC             Wiseguy NY Pizza               NaN
# 393  Washington DC                        Jaleo               NaN
# 394  Washington DC                 The Partisan               NaN
# 395  Washington DC                       Rasika               NaN
# 396  Washington DC  The Source by Wolfgang Puck               NaN
# 397  Washington DC                     Masseria               NaN
# 398  Washington DC             Toki Underground               NaN
# 399  Washington DC                      Maketto               NaN
# 400  Washington DC           Hank's On The Hill               NaN
# 401  Washington DC                Rose's Luxury               NaN
# 402  Washington DC               Osteria Morini               NaN
# 403  Washington DC                    Beefsteak               NaN
# 404  Washington DC         Bourbon Steak Lounge               NaN
# 405  Washington DC               Kapnos Taverna               NaN
# 406  Washington DC                          SER               NaN
# 407  Washington DC              2941 Restaurant               NaN
#
#      Michelin_stars
# 0               2.0
# 1               2.0
# 2               3.0
# 3               1.0
# 4               1.0
# 5               1.0
# 6               1.0
# 7               1.0
# 8               1.0
# 9               1.0
# 10              3.0
# 11              1.0
# 12              1.0
# 13              1.0
# 14              1.0
# 15              1.0
# 16              1.0
# 17              1.0
# 18              2.0
# 19              1.0
# 20              1.0
# 21              1.0
# 22              2.0
# 23              1.0
# 24              1.0
# 25              1.0
# 26              1.0
# 27              2.0
# 28              1.0
# 29              1.0
# ..              ...
# 378             NaN
# 379             NaN
# 380             NaN
# 381             NaN
# 382             NaN
# 383             NaN
# 384             NaN
# 385             NaN
# 386             NaN
# 387             NaN
# 388             NaN
# 389             NaN
# 390             NaN
# 391             NaN
# 392             NaN
# 393             NaN
# 394             NaN
# 395             NaN
# 396             NaN
# 397             NaN
# 398             NaN
# 399             NaN
# 400             NaN
# 401             NaN
# 402             NaN
# 403             NaN
# 404             NaN
# 405             NaN
# 406             NaN
# 407             NaN
#
# [408 rows x 4 columns]

# %%
df=df[df.name!='Untitled']

# %%
df.name.value_counts(dropna=False)
# Out:
# Bad Saint                            2
# The Royal                            2
# Jaleo                                2
# Boqueria                             2
# Thip Khao                            2
# Zaytinya                             2
# Maketto                              2
# Topolobampo                          1
# New Malaysia                         1
# Sushiko                              1
# Yusho*                               1
# Zoma                                 1
# Nyonya                               1
# Ichimura at Brushstroke              1
# Del Posto                            1
# Mexicosina                           1
# Marlow & Sons                        1
# TAC Quick                            1
# Ciccio                               1
# Terrapin Creek                       1
# Sepia                                1
# Mott Street                          1
# Everest                              1
# Campton Place                        1
# Xixa                                 1
# Maruya                               1
# Masa                                 1
# Solbar                               1
# Phoenix Garden                       1
# Juni                                 1
#                                     ..
# Pearl & Ash                          1
# Miss Mamie's Spoonbread Too          1
# Plumed Horse                         1
# Timber Pizza Company                 1
# Bar Pilar                            1
# Keiko à Nob Hill                     1
# 2Amys                                1
# Junoon                               1
# Shalom Japan                         1
# ANXO Cidery & Pinxtos Bar            1
# Dovetail                             1
# Girl and the Goat                    1
# County Barbeque                      1
# Dove's Luncheonette*                 1
# Two                                  1
# Good Fork                            1
# Chez TJ                              1
# Basil Brick Oven Pizza               1
# GT Fish and Oyster                   1
# Pippali                              1
# Lea                                  1
# Kung Fu Little Steamed Buns Ramen    1
# Elizabeth                            1
# Umi NOM                              1
# SPQR                                 1
# Marea                                1
# Aster                                1
# Betony                               1
# Brushstroke                          1
# Casa del Chef Bistro                 1
# Name: name, dtype: int64

# %%
L=["Bad Saint ",
"The Royal",
"Jaleo",
"Boqueria",
"Thip Khao",
"Zaytinya",
"Maketto"]
df[df.name =="Jaleo"]
# Out:
#               city   name neighborhood  Michelin_stars
# 347  Washington DC  Jaleo          NaN             0.0
# 393  Washington DC  Jaleo          NaN             NaN

# %%
all_restaurant[all_restaurant.name=="Acadia"]
# Out:
#          categories     city              id    name  price  rating  \
# 108  American (New)  Chicago  acadia-chicago  Acadia      4     4.0
#
#      review_count
# 108           334

# %%
all_restaurant.city.value_counts()
# Out:
# San Francisco       51
# New York            50
# Washington          45
# Chicago             38
# Brooklyn             6
# Long Island City     1
# Flushing             1
# Astoria              1
# Annandale            1
# Jackson Heights      1
# Sausalito            1
# Name: city, dtype: int64

# %%
all_restaurant['Michelin']=0
notfouned=[]

for i in range (0,len(all_restaurant)):
    try:
        all_restaurant['Michelin'].iloc[i] =df.Michelin_stars[df.name==all_restaurant.name.iloc[i]].iloc[0]
        
    except:
        notfound.append(all_restaurant.name.iloc[i])

# %%
all_restaurant
# Out:
#                  categories              city  \
# 0                Sushi Bars     San Francisco
# 1            American (New)     San Francisco
# 2                   Mexican     San Francisco
# 3                    French     San Francisco
# 4                   Italian     San Francisco
# 5            American (New)     San Francisco
# 6                Sushi Bars     San Francisco
# 7                  Japanese     San Francisco
# 8                    French     San Francisco
# 9            American (New)     San Francisco
# 10                   French     San Francisco
# 11           American (New)     San Francisco
# 12   American (Traditional)     San Francisco
# 13              Steakhouses     San Francisco
# 14                   French     San Francisco
# 15           American (New)     San Francisco
# 16                   French     San Francisco
# 17                   French     San Francisco
# 18           American (New)     San Francisco
# 19           American (New)     San Francisco
# 20                   French     San Francisco
# 21           American (New)     San Francisco
# 22       Tapas/Small Plates     San Francisco
# 23                   French     San Francisco
# 24                 Moroccan     San Francisco
# 25               Sushi Bars     San Francisco
# 26           American (New)     San Francisco
# 27           American (New)     San Francisco
# 28           American (New)     San Francisco
# 29                  Italian     San Francisco
# ..                      ...               ...
# 166                  French          New York
# 167                 Italian          New York
# 168                 Lounges          New York
# 169                  Indian          New York
# 170          American (New)          New York
# 171                  French          New York
# 172          American (New)          New York
# 173                    Thai          New York
# 174              Portuguese          New York
# 175                 British          New York
# 176                   Ramen          New York
# 177            Coffee & Tea          New York
# 178                 Mexican  Long Island City
# 179               Malaysian          New York
# 180                  French          Brooklyn
# 181  American (Traditional)          Brooklyn
# 182                    Thai          New York
# 183                   Ramen           Astoria
# 184              Vietnamese          New York
# 185                Japanese          New York
# 186               Wine Bars          New York
# 187                 Mexican          Brooklyn
# 188                  German          New York
# 189                 Italian          New York
# 190                Szechuan          New York
# 191            Asian Fusion          New York
# 192                    Thai   Jackson Heights
# 193               Taiwanese          Flushing
# 194                    Thai          New York
# 195                  Indian          Brooklyn
# 22                    State Bird Provisions      3     4.5          1935
# 23                                   Bouche      3     4.0           589
# 24                        Mourad Restaurant      3     4.0           412
# 25                             Zushi Puzzle      3     4.0          1264
# 26                         Range Restaurant      3     4.0          1684
# 27                                 Hakkasan      3     4.0          1123
# 28                                  Octavia      3     4.0           241
# 29                                    Bacco      3     4.0           397
# ..                                      ...    ...     ...           ...
# 166                             Degustation      3     4.0           592
# 167                         MAMO Restaurant      3     4.0           112
# 168                   The Modern - Bar Room      3     4.0           406
# 169                                Tamarind      3     4.0           568
# 170                                Perry St      3     4.0           771
# 171               Nougatine at Jean-Georges      3     4.0           907
# 172                                     Nix      3     4.0           112
# 173                             Uncle Boons      3     4.0           378
# 174                                   Aldea      3     4.0           488
# 175                          The Clocktower      3     4.0           148
# 176                               Ippudo NY      2     4.0          8436
# 177                                     C&B      2     4.5           103
# 178                            Casa Enrique      2     4.0           603
# 179                                    Rasa      2     4.0           361
# 180                                 Le Fond      2     4.5            82
# 181                     Delaware and Hudson      2     4.0           178
# 182                              Somtum Der      2     4.0           407
# 183                          HinoMaru Ramen      2     4.0           586
# 184                                    OBAO      2     4.0          1021
# 185                                 Soba-ya      2     4.0          1112
# 186         Upholstery Store: Food and Wine      2     4.0            73
# 187                           Jolie Cantina      2     4.0           269
# 188                           Café Sabarsky      2     4.0           373
# 189                                 Mercato      2     4.0           524
# 190                              Café China      2     3.5           654
# 191                      Sachi Asian Bistro      2     4.0           101
# 192                               Auttharos      2     4.0           231
# 193  Main Street Imperial Taiwanese Gourmet      2     4.0           223
# 194                                    OBAO      2     3.5           561
# 195                        The Chinese Club      2     4.0            44
#
#      Michelin
# 0         0.0
# 1         1.0
# 2         1.0
# 3         0.0
# 4         2.0
# 5         3.0
# 6         1.0
# 7         0.0
# 8         1.0
# 9         1.0
# 10        2.0
# 11        3.0
# 12        1.0
# 13        0.0
# 14        2.0
# 15        1.0
# 16        0.0
# 17        0.0
# 18        0.0
# 19        1.0
# 20        0.0
# 21        0.0
# 22        1.0
# 23        0.0
# 24        0.0
# 25        0.0
# 26        0.0
# 27        0.0
# 28        1.0
# 29        0.0
# ..        ...
# 166       0.0
# 167       0.0
# 168       0.0
# 169       0.0
# 170       0.0
# 171       0.0
# 172       0.0
# 173       1.0
# 174       1.0
# 175       0.0
# 176       0.0
# 177       0.0
# 178       1.0
# 179       1.0
# 180       0.0
# 181       0.0
# 182       1.0
# 183       0.0
# 184       0.0
# 185       0.0
# 186       0.0
# 187       0.0
# 188       0.0
# 189       0.0
# 190       1.0
# 191       0.0
# 192       0.0
# 193       0.0
# 194       0.0
# 195       0.0
#
# [196 rows x 8 columns]

# %%
notfound2=[]
df['categories']=np.nan
df["price"]=np.nan
df["rating"]=np.nan
df["review_count"]=np.nan
for i in range (0,len(df)):
    try:
        s =all_restaurant.name[all_restaurant.name==df.name.iloc[i]].index
        print all_restaurant.categories[s].iloc[0]
        df['categories'].iloc[i]=all_restaurant.categories[s].iloc[0]
        df["price"].iloc[i]=all_restaurant.price[s].iloc[0]
        df["rating"].iloc[i]=all_restaurant.rating[s].iloc[0]
        df["review_count"].iloc[i]=all_restaurant.review_count[s].iloc[0]
    except:
        notfound2.append(df.name.iloc[i])
# Out:
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# American (New)
# American (New)
# American (New)
# American (New)
# French
# American (New)
# American (New)
# Hotels
# American (New)
# Korean
# American (New)
# American (New)
# American (New)
# Italian
# Mexican
# American (New)
# Italian
# American (New)
# French
# American (New)
# Mexican
# American (New)
# American (New)
# French
# Thai
# American (New)
# Modern European
# American (New)
# American (New)
# American (New)
# American (New)
# Sushi Bars
# French
# Malaysian
# American (New)
# American (New)
# Italian
# American (Traditional)
# Tapas/Small Plates
# Portuguese
# American (Traditional)
# American (New)
# French
# Szechuan
# Mexican
# American (New)
# French
# American (New)
# Bars
# American (New)
# American (New)
# French
# Korean
# Japanese
# French
# Italian
# French
# American (New)
# American (New)
# French
# Thai
# Thai
# Ramen
# American (New)
# Italian
# Chinese
# Thai
# Asian Fusion
# Tapas/Small Plates
# Bars
# Filipino
# Mediterranean
# Laotian
# Greek
# Italian
# Laotian
# Filipino
# Cocktail Bars
# Brasseries
# Thai
# Greek
# Indian
# Taiwanese
# American (New)

# %%
g = sns.FacetGrid(Michelin, col="Michelin_stars")  
g.map(plt.scatter,  "price","rating")

# %%
Michelin=df.copy()
Michelin=Michelin.drop("neighborhood",axis=1)
Michelin_model=Michelin.dropna()
Michelin_predict=Michelin[(Michelin.city=="Washington DC")]
Michelin_predict=Michelin_predict[Michelin_predict.Michelin_stars!=0]
Michelin_predict=Michelin_predict.drop("Michelin_stars",axis=1)
Michelin_predict
# Out:
#               city                         name      categories  price  \
# 359  Washington DC    ANXO Cidery & Pinxtos Bar             NaN    NaN
# 360  Washington DC                      Bindaas             NaN    NaN
# 361  Washington DC              Bullfrog Bagels             NaN    NaN
# 362  Washington DC                     Casolare             NaN    NaN
# 363  Washington DC       District Distilling Co             NaN    NaN
# 364  Washington DC                       Haikan             NaN    NaN
# 365  Washington DC                    HalfSmoke             NaN    NaN
# 366  Washington DC                        Hazel             NaN    NaN
# 367  Washington DC                Little Coco's             NaN    NaN
# 368  Washington DC                  RPM Italian         Italian    3.0
# 369  Washington DC             Smoked & Stacked             NaN    NaN
# 370  Washington DC         Timber Pizza Company             NaN    NaN
# 371  Washington DC                     Republic             NaN    NaN
# 372  Washington DC                      Sushiko             NaN    NaN
# 373  Washington DC                    Thip Khao         Laotian    2.0
# 374  Washington DC                    Bad Saint        Filipino    2.0
# 375  Washington DC      Jack Rose Dining Saloon             NaN    NaN
# 376  Washington DC                 Tail Up Goat   Cocktail Bars    3.0
# 377  Washington DC                 Izakaya Seki             NaN    NaN
# 378  Washington DC                 Compass Rose             NaN    NaN
# 379  Washington DC                    Bar Pilar             NaN    NaN
# 380  Washington DC                    Convivial             NaN    NaN
# 381  Washington DC                   The Dabney             NaN    NaN
# 382  Washington DC                    The Royal             NaN    NaN
# 383  Washington DC                 Le Diplomate      Brasseries    3.0
# 384  Washington DC                      Estadio             NaN    NaN
# 385  Washington DC                 Little Serow            Thai    3.0
# 386  Washington DC                    Iron Gate             NaN    NaN
# 387  Washington DC                  Bombay Club             NaN    NaN
# 388  Washington DC            Espita Mezcaleria             NaN    NaN
# 389  Washington DC                    Del Campo             NaN    NaN
# 390  Washington DC                     Zaytinya           Greek    3.0
# 391  Washington DC                      Daikaya             NaN    NaN
# 392  Washington DC             Wiseguy NY Pizza             NaN    NaN
# 393  Washington DC                        Jaleo             NaN    NaN
# 394  Washington DC                 The Partisan             NaN    NaN
# 395  Washington DC                       Rasika          Indian    3.0
# 396  Washington DC  The Source by Wolfgang Puck             NaN    NaN
# 397  Washington DC                     Masseria             NaN    NaN
# 398  Washington DC             Toki Underground       Taiwanese    2.0
# 399  Washington DC                      Maketto             NaN    NaN
# 400  Washington DC           Hank's On The Hill             NaN    NaN
# 401  Washington DC                Rose's Luxury  American (New)    3.0
# 402  Washington DC               Osteria Morini             NaN    NaN
# 403  Washington DC                    Beefsteak             NaN    NaN
# 404  Washington DC         Bourbon Steak Lounge             NaN    NaN
# 405  Washington DC               Kapnos Taverna             NaN    NaN
# 406  Washington DC                          SER             NaN    NaN
# 407  Washington DC              2941 Restaurant             NaN    NaN
#
#      rating  review_count
# 359     NaN           NaN
# 360     NaN           NaN
# 361     NaN           NaN
# 362     NaN           NaN
# 363     NaN           NaN
# 364     NaN           NaN
# 365     NaN           NaN
# 366     NaN           NaN
# 367     NaN           NaN
# 368     4.5         131.0
# 369     NaN           NaN
# 370     NaN           NaN
# 371     NaN           NaN
# 372     NaN           NaN
# 373     4.5         461.0
# 374     4.5         194.0
# 375     NaN           NaN
# 376     4.5         129.0
# 377     NaN           NaN
# 378     NaN           NaN
# 379     NaN           NaN
# 380     NaN           NaN
# 381     NaN           NaN
# 382     NaN           NaN
# 383     4.0        1746.0
# 384     NaN           NaN
# 385     4.0         494.0
# 386     NaN           NaN
# 387     NaN           NaN
# 388     NaN           NaN
# 389     NaN           NaN
# 390     4.0        3312.0
# 391     NaN           NaN
# 392     NaN           NaN
# 393     NaN           NaN
# 394     NaN           NaN
# 395     4.5        2231.0
# 396     NaN           NaN
# 397     NaN           NaN
# 398     4.0        1581.0
# 399     NaN           NaN
# 400     NaN           NaN
# 401     4.5        1231.0
# 402     NaN           NaN
# 403     NaN           NaN
# 404     NaN           NaN
# 405     NaN           NaN
# 406     NaN           NaN
# 407     NaN           NaN

# %%
Michelin_model.categories.unique()
# Out:
# array([u'American (New)', u'French', u'Hotels', u'Korean', u'Italian',
#        u'Mexican', u'Thai', u'Modern European', u'Sushi Bars',
#        u'Malaysian', u'American (Traditional)', u'Tapas/Small Plates',
#        u'Portuguese', u'Szechuan', u'Bars', u'Japanese', u'Ramen',
#        u'Chinese', u'Asian Fusion', u'Filipino', u'Mediterranean',
#        u'Laotian', u'Greek'], dtype=object)

# %%
from sklearn import cross_validation
from sklearn.cross_validation import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

le=preprocessing.LabelEncoder()
std=StandardScaler()
X = Michelin_model[["price","rating","review_count","categories"]]
X['categories']=le.fit_transform(X.categories)
X=std.fit_transform(X)
Y = Michelin_model['Michelin_stars']
num_folds = 10
num_instances = len(X)
seed = 7
kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)
# create the sub models
estimators = []
model1 = LogisticRegression()
estimators.append(('logistic', model1))
model2 = DecisionTreeClassifier()
estimators.append(('cart', model2))
model3 = SVC()
estimators.append(('svm', model2))
# create the ensemble model
ensemble = VotingClassifier(estimators,voting='hard')
results = cross_validation.cross_val_score(ensemble, X, Y, cv=kfold)
print(results.mean())
print results
# Out:
# 0.421428571429
# [ 0.625       0.75        0.625       0.5         0.42857143  0.
#   0.28571429  0.42857143  0.42857143  0.14285714]
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
z=Michelin_predict.dropna()
z_predict=z[["price","rating","review_count","categories"]]

z_predict['categories']=le.fit_transform(z_predict.categories)
z_predict=std.fit_transform(z_predict)
# Out:
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
eclf1 = ensemble.fit(X, Y)
print (eclf1.predict(z_predict))
# Out:
# [ 1.  0.  0.  1.  1.  1.  1.  3.  1.  3.]

# %%
def score(name,model):
    cv = StratifiedKFold(Y, n_folds=5, shuffle=True, random_state=55)
    s = cross_validation.cross_val_score(model, X, Y, cv=cv, n_jobs=-1)
    print "{} Score:\t{:0.3} ± {:0.3}".format(name, s.mean().round(3), s.std().round(3))

# %%
print score("logistic",model1)
print score("CART",model2)
print score("SVM",model2)
# Out:
# logistic Score:	0.521 ± 0.106
# None
# CART Score:	0.349 ± 0.058
# None
# SVM Score:	0.349 ± 0.058
# None

# %%
z
# Out:
#               city              name      categories  price  rating  \
# 368  Washington DC       RPM Italian         Italian    3.0     4.5
# 373  Washington DC         Thip Khao         Laotian    2.0     4.5
# 374  Washington DC         Bad Saint        Filipino    2.0     4.5
# 376  Washington DC      Tail Up Goat   Cocktail Bars    3.0     4.5
# 383  Washington DC      Le Diplomate      Brasseries    3.0     4.0
# 385  Washington DC      Little Serow            Thai    3.0     4.0
# 390  Washington DC          Zaytinya           Greek    3.0     4.0
# 395  Washington DC            Rasika          Indian    3.0     4.5
# 398  Washington DC  Toki Underground       Taiwanese    2.0     4.0
# 401  Washington DC     Rose's Luxury  American (New)    3.0     4.5
#
#      review_count
# 368         131.0
# 373         461.0
# 374         194.0
# 376         129.0
# 383        1746.0
# 385         494.0
# 390        3312.0
# 395        2231.0
# 398        1581.0
# 401        1231.0

# %%
z['predicted']=eclf1.predict(z_predict)
# Out:
# /Users/freh_mac/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100) # initialize
rf.fit(X, Y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf.predict(z_predict)
# Out:
# array([ 1.,  0.,  0.,  1.,  1.,  1.,  1.,  3.,  1.,  3.])

# %%
z[['name','predicted']].to_csv("submission")
# Out:
#                  name  predicted
# 368       RPM Italian        1.0
# 373         Thip Khao        0.0
# 374         Bad Saint        0.0
# 376      Tail Up Goat        1.0
# 383      Le Diplomate        1.0
# 385      Little Serow        1.0
# 390          Zaytinya        1.0
# 395            Rasika        3.0
# 398  Toki Underground        1.0
# 401     Rose's Luxury        3.0
